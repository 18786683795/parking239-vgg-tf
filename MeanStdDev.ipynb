# %%
import numpy as np
import matplotlib.pyplot as plt
import pylab

# %matplotlib inline

# %%
im = np.load('/media/ubuntu/DATA/PARKING_239/WORK/mean.npy')
print(im.shape)
pylab.imshow(im, origin='lower', interpolation='nearest', cmap='gray')
#plt.imshow(im)
# Out:
# (224, 224, 3)

# %%
print(im[110,0], np.max(im), np.min(im))
# Out:
# [ 82.3474  85.5715  87.4698] 129.69965 7.59605

# %%
im = np.load('/media/ubuntu/DATA/PARKING_239/WORK/std.npy')
print(im.shape)
pylab.imshow(im, origin='lower',  cmap='gray')
# Out:
# (224, 224, 3)

# %%
print(im[110,0], np.max(im), np.min(im))
# Out:
# [ 56.6834051   57.04134279  61.4948444 ] 84.2414629814 24.0114217488
